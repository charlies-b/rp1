# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('network-lysosome-biogenesis-5.csv')

# %%
edgelist = df[['node1', 'node2']].copy()
edgelist.node1 = edgelist.node1.str.replace(' ', '_')
edgelist.node2 = edgelist.node2.str.replace(' ', '_')

edgelist = edgelist.values.tolist()

# %%
f = open('edgelist-lysosome-biogenesis-1', 'w')
for edge in edgelist:
    f.write('{0}\t{1}\n'.format(edge[0], edge[1]))
f.close()

# %%
f = open('edgelist-lysosome-biogenesis-1', 'r')
for line in f:
    print(line, end="")
f.close()
# Out:
# Lysosome_Destined_Cargo	Lysosome_Destined_Cargo:AP-1:Arf1-GTP:beta-Arrestin-1:Vamp_Complex
# Vamp	Lysosome_Destined_Cargo:AP-1:Arf1-GTP:beta-Arrestin-1:Vamp_Complex
# Lysosome_Destined_Cargo	Lysosome_Destined_Cargo:AP-1:Arf1-GTP:beta-Arrestin-1:Vamp_Complex
# ARRB1	Lysosome_Destined_Cargo:AP-1:Arf1-GTP:beta-Arrestin-1:Vamp_Complex
# Arf1-GTP	Lysosome_Destined_Cargo:AP-1:Arf1-GTP:beta-Arrestin-1:Vamp_Complex
# AP-1_Complex	Lysosome_Destined_Cargo:AP-1:Arf1-GTP:beta-Arrestin-1:Vamp_Complex
# Clathrin_Triskelion	Lysosome_Destined_Cargo:AP-1:Beta-arrestin:Vamp:Clathrin_Triskelion:Dynamin:Endophilin_Complex
# SH3GL2	Lysosome_Destined_Cargo:AP-1:Beta-arrestin:Vamp:Clathrin_Triskelion:Dynamin:Endophilin_Complex
# Lysosome_Destined_Cargo:AP-1:Arf1-GTP:beta-Arrestin-1:Vamp_Complex	Lysosome_Destined_Cargo:AP-1:Beta-arrestin:Vamp:Clathrin_Triskelion:Dynamin:Endophilin_Complex
# DNM2	Lysosome_Destined_Cargo:AP-1:Beta-arrestin:Vamp:Clathrin_Triskelion:Dynamin:Endophilin_Complex
# Clathrin_Triskelion	Arf1-GDP
# SH3GL2	Arf1-GDP
# Lysosome_Destined_Cargo:AP-1:Arf1-GTP:beta-Arrestin-1:Vamp_Complex	Arf1-GDP
# DNM2	Arf1-GDP
# DNM2	SH3GL2
# Lysosome_Destined_Cargo:AP-1:Beta-arrestin:Vamp:Clathrin_Triskelion:Dynamin:Endophilin_Complex	SH3GL2
# Lysosome_Destined_Cargo:AP-1:Beta-arrestin:Vamp:Clathrin_Triskelion:Dynamin:Endophilin_Complex	DNM2
# Lysosome_Destined_Cargo:AP-1:Beta-arrestin:Vamp:Clathrin_Triskelion:Dynamin:Endophilin_Complex	Lysosome_Cargo:AP-1:Beta-arrestin:Clathrin_Triskelion:Vamp_Complex
# HSC70:Auxillin_Complex	HSC70:Auxillin_Complex
# Lysosome_Cargo:AP-1:Beta-arrestin:Clathrin_Triskelion:Vamp_Complex	HSC70:Auxillin_Complex
# HSC70:Auxillin_Complex	Lysosome_Cargo
# Lysosome_Cargo:AP-1:Beta-arrestin:Clathrin_Triskelion:Vamp_Complex	Lysosome_Cargo
# HSC70:Auxillin_Complex	Lysosome_Cargo
# Lysosome_Cargo:AP-1:Beta-arrestin:Clathrin_Triskelion:Vamp_Complex	Lysosome_Cargo
# HSC70:Auxillin_Complex	ARRB1
# Lysosome_Cargo:AP-1:Beta-arrestin:Clathrin_Triskelion:Vamp_Complex	ARRB1
# HSC70:Auxillin_Complex	Clathrin_Triskelion
# Lysosome_Cargo:AP-1:Beta-arrestin:Clathrin_Triskelion:Vamp_Complex	Clathrin_Triskelion
# HSC70:Auxillin_Complex	AP-1_Complex
# Lysosome_Cargo:AP-1:Beta-arrestin:Clathrin_Triskelion:Vamp_Complex	AP-1_Complex
# HSC70:Auxillin_Complex	Vamp
# Lysosome_Cargo:AP-1:Beta-arrestin:Clathrin_Triskelion:Vamp_Complex	Vamp
# AP4	AP4:APP
# APP(18-770)	AP4:APP
# AP4:APP	AP4:APP
# CHMP2A	AP1G2:HGS:CHMP2A
# AP1G2	AP1G2:HGS:CHMP2A
# HGS	AP1G2:HGS:CHMP2A
# CLAT:AP1:CLVS	CLAT:AP1:CLVS:PI(3,5)P2
# TXNDC5	BLOC-1_Complex
# BLOC1S3	BLOC-1_Complex
# BLOC1S1	BLOC-1_Complex
# DTNBP1	BLOC-1_Complex
# NAPA	BLOC-1_Complex
# BLOC1S6	BLOC-1_Complex
# BLOC1S4	BLOC-1_Complex
# BLOC-1_Complex	OUTPUT
# CLAT:AP1:CLVS:PI(3,5)P2	OUTPUT
# AP4:APP	OUTPUT
# Vamp	OUTPUT
# Lysosome_Cargo	OUTPUT
# AP1G2:HGS:CHMP2A	OUTPUT
# VAMP2	Vamp
# VAMP7	Vamp
# VAMP8	Vamp
# ARF1	Arf1-GTP
# AP1G1	AP-1_Complex
# AP1M1	AP-1_Complex
# AP1M2	AP-1_Complex
# AP1S1	AP-1_Complex
# AP1S2	AP-1_Complex
# AP1S3	AP-1_Complex
# AP1B1	AP-1_Complex
# CLTC-1	Clathrin_Triskelion
# Clathrin_light_chain	Clathrin_Triskelion
# HSPA8	HSC70:Auxillin_Complex
# DNAJC6	HSC70:Auxillin_Complex
# ARF1	Arf1-GDP
# CTSZ	Lysosome_Cargo
# DNASE2	Lysosome_Cargo
# TXNDC5	Lysosome_Cargo
# GNS	Lysosome_Cargo
# M6PR	Lysosome_Cargo
# BLOC1S1	Lysosome_Cargo
# CLVS	CLVS1
# CLVS	CLVS2
# CLAT	CLTA
# CLAT	CLTB
# CLAT	CLTC
# CLVS	CLAT:AP1:CLVS
# CLAT	CLAT:AP1:CLVS
# IpdC	CORO1A
# esxH:esxG	HGS
# PtpA	TRIM27
# CORO1A	APP(18-770)
# HGS	BLOC1S1
# TRIM27	HGS
# TRIM27	AP1M1
# TRIM27	DTNBP1

# %%
G = nx.read_edgelist('edgelist-lysosome-biogenesis-1')

# %%
plt.figure(figsize=(24,24))
nx.draw(G, node_size=50, with_labels= True)
